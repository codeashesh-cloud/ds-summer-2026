# %% [markdown]
# # operator precedence
# python follows the PEMDAS (parenthesis, exponents, multiplication/division, addition/subtraction)
#
# and is evaluated from left to right except exponentiation. exponentiation evaluates from right to left
