# %%
#conditional statements

# %%
#if elif and else statements

# %%
a=7

# %%
if (a>10):
    print("greater than 10")
elif (a>20):
    print("greater than 20")
else:
    print("smaller")
# Out:
# greater than 10

# %% [markdown]
# ## functions

# %%
def avg(a,b): # a and b are called arguments
    return (a+b)/2

# %%
avg(9,10)
# Out:
# 9.5

# %%
def mul(a,b=7):# function with default value or default arguments
    return a*b

# %%
mul(8) #when b is not given the default arguments is used
# Out:
# 56
