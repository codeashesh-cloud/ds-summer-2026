# %%
a=10
b=5

# %% [markdown]
# ## arithmetic operators

# %%
a+b
# Out:
# 15

# %%
a-b
# Out:
# 5

# %%
a*b
# Out:
# 50

# %%
a/b # answer is always a floatig point for division
# Out:
# 2.0

# %%
a//b #floor dividion: ans is quotient
# Out:
# 2

# %%
a%b #modulus gives the remainder
# Out:
# 0

# %%
a**b #exponentiation or power
# Out:
# 100000

# %% [markdown]
# ## comparison operators
# the result of it is always a boolean expression that is either true or false

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# False

# %% [markdown]
# ## logical operators
# they only operate in boolean operations

# %%
a=True
b=False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not b
# Out:
# True

# %% [markdown]
# ## assignment operator

# %%
#it is easy
