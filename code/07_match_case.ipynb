# %%
code=500

# %%
match code:
    case 200:
        print("Response Ok")
    case 400:
        print("bad")
    case 404:
        print("Not Found")
    case _:
        print("Nothing Matched")
print("end of the program")
# Out:
# Nothing Matched
# end of the program
