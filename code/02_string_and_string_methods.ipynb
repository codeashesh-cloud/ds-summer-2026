# %%
name="ashesh"

# %%
type(name)
# Out:
# str

# %% [markdown]
# string is a collection of characters

# %% [markdown]
# there are lots of string methods

# %%
name.upper()
# Out:
# 'ASHESH'

# %%
name.endswith("h")
# Out:
# True

# %% [markdown]
# to use the methods just press the .then tab. python will suggest variosu string methods

# %%
s="codewithHarry"

# %%
print(len(s))
# Out:
# 13

# %% [markdown]
# ## this is called string slicing

# %%
print(s[0:5])
# Out:
# codew

# %%
print(s[0:-1])
# Out:
# codewithHarr

# %% [markdown]
# ## to convert the negative to positive just add the len

# %%
print(s[1:12])
# Out:
# odewithHarr
