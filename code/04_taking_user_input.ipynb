# %%
a=input("enter the value of a ")
# Out:
# enter the value of a  90

# %%
b=input("enter the value of b: ")
# Out:
# enter the value of b:  10

# %%
print(a+b)
# Out:
# 9010

# %% [markdown]
# ## the result of input function is always a str
# we have to typecast str to int before evaluating something

# %%
print(int(a)+int(b))
# Out:
# 100
