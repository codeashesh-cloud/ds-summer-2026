# %% [markdown]
# # list and list methods

# %% [markdown]
# is an ordered, mutable collection of elements. (string was immutable )
#
# can contain elements of different data types.

# %%
## creating an empty list
my_list=[]

## list with elements
a=[1, 2, 3, 4, 5]

# list with different data types
b=[1, "ashesh", 9.6,True]

# %%
a[0]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## we can cahnge elements as it is mutable( not like string)

# %%
a[0]=7

# %%
print(a)
# Out:
# [7, 2, 3, 4, 5]

# %% [markdown]
# ## all the methdos of string used to give us new string and doesnot cahnge the original string.
# ## but all methods of list modifies the original list

# %%
a.append(9)

# %%
a
# Out:
# [7, 2, 3, 4, 5, 9]

# %%
c=[0,7,8]

# %%
a.extend(c)

# %%
a
# Out:
# [7, 2, 3, 4, 5, 9, 0, 7, 8]

# %%
a.insert(1,200) # inserting 200 at index 1

# %%
b.pop(1)
# Out:
# 'ashesh'

# %%
b
# Out:
# [1, 9.6, True]

# %%
a.index(9)
# Out:
# 6

# %% [markdown]
# ## we can make nested list too

# %%
y=[7,3,"ashesh",[0,9,8.9],3.4]

# %%
print(y)
# Out:
# [7, 3, 'ashesh', [0, 9, 8.9], 3.4]

# %%
print(y[3])
# Out:
# [0, 9, 8.9]

# %%
print(y[3][1])
# Out:
# 9

# %% [markdown]
# ## list concatenation

# %%
e=a+y

# %%
print(e)
print(a)
print(y)
# Out:
# [7, 200, 2, 3, 4, 5, 9, 0, 7, 8, 7, 3, 'ashesh', [0, 9, 8.9], 3.4]
# [7, 200, 2, 3, 4, 5, 9, 0, 7, 8]
# [7, 3, 'ashesh', [0, 9, 8.9], 3.4]

# %% [markdown]
# ## splitting the string into list

# %%
s="ashesh-dipsan-rohan-nischal"

# %%
z=s.split("-")

# %%
print(z)
# Out:
# ['ashesh', 'dipsan', 'rohan', 'nischal']
