# %% [markdown]
# ## f-strings are the most efficient and recommended way to format the string in modern python

# %%
s="ashesh"

# %%
s[0]
# Out:
# 'a'

# %% [markdown]
# ## but we cannot do this

# %%
#s[0]=7

# %% [markdown]
# ## this si because the string is immutable. so we cannot change anything once it is created .

# %% [markdown]
# ## but you might think taht we canhed this earlier using the string methods like this

# %%
a=s.upper()

# %%
print(a)
# Out:
# ASHESH

# %% [markdown]
# ## this is actually not changing the string.

# %%
print(s)
# Out:
# ashesh

# %% [markdown]
# ## if we alter anything using the string methods, ity creates new variable and sttore newly created variable in that.
# ## original string is never changed as it is immutable

# %%
name="ashesh"
age=22

# %% [markdown]
# ## there are 2 ways to prin this

# %%
print("my name is",name,"and my age is",age)
print(f"my name is {name} and my age is {age}") # using fstring
# Out:
# my name is ashesh and my age is 22
# my name is ashesh and my age is 22

# %% [markdown]
# # f string is a way to include the variables inside the string

# %%
print(f"{'Python':<10}")  # Left-align by 10 characters
print(f"{'Python':>10}")  # Right-align
print(f"{'Python':^10}")  # Center-align
# Out:
# Python
#     Python
#   Python

# %%
#:<10 → The < symbol means left-align the text within a total width of 10 characters.
