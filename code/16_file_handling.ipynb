# %% [markdown]
# # file handling
# it allows python program to read, write and manipulate the files stored on the disk. Python provides the buil;t-in functions for working with files.

# %% [markdown]
# ## opening a file

# %%
f= open("file_handling.txt", "r")

# %%
f.read()
# Out:
# 'ashesh\nis\na great boy. he is perfect candidate for your company \nhe is the perfect data scientist\nplease hire him\n'

# %%
f.close()

# %%
s=" this is a nice way to learn a data science."

# %%
f=open("ashesh.txt", "w")

# %%
f.write(s)
# Out:
# 44

# %%
f.close()
