# %%
a=5

# %%
print (a)
# Out:
# 5

# %%
b=8

# %%
a+b
# Out:
# 13

# %%
name="ashesh"

# %%
name
# Out:
# 'ashesh'

# %%
print("hello world")
# Out:
# hello world

# %%
# this is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# this is now important concept

# %%
a="89"

# %%
b="75"

# %%
print(a+b) #they are concatenated because they are string not the int
# Out:
# 8975

# %% [markdown]
# typecasting needs to be done for adding them

# %%
x=int(a)

# %%
y=int(b)

# %%
print(x+y)
# Out:
# 164
