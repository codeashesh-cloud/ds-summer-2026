# %% [markdown]
# # tuples
# it is similar to list but only difference is it is not mutable. that is it is immutable like string.

# %%
## creating an empty tuple
my_tuple=()
print(type(my_tuple))
# Out:
# <class 'tuple'>

# %%
# tuple withe elements
new_tuple=(4,3,10,20)

# %%
#tuple with various data types
a=(2,4.5,"ram",True)

# %% [markdown]
# # immutable so cannot be change

# %%
print(a[0])
# Out:
# 2

# %%
#this cannot be done
#a[0]=5
